# %%
#Data analysis and manipulation tool
import pandas as pd
#Wide variety of mathematical operations on arrays
import numpy as np
#Tool for plotting
import matplotlib.pyplot as plt
#Google Drive
from google.colab import drive

# %%
#Mount Google Drive to Google Colab
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
#Verify mount is correct
# !ls -l gdrive/MyDrive/Colab\ Notebooks/TEMPTERM/csv
# Out:
# total 414
# -rw------- 1 root root 250329 Jan 19 22:45 ALL-tempterm-no-control.txt
# -rw------- 1 root root 173144 Apr 12 20:39 ALL-tempterm-with-control.txt

# %%
#The "read_csv" method allows us to read a CSV
data_mult = pd.read_csv("gdrive/MyDrive/Colab Notebooks/TEMPTERM/csv/ALL-tempterm-no-control.txt", header = None)
#Cov = pd.read_csv("path/to/file.txt", sep='\t', header=None)
data_mult.columns = ["ID", "Temp In", "Temp Out", "ClientIP", "SensorID", "DateTime"]

# %%
#Show information about dataset
data_mult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4398 entries, 0 to 4397
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        4398 non-null   int64
#  1   Temp In   4398 non-null   float64
#  2   Temp Out  4398 non-null   float64
#  3   ClientIP  4398 non-null   object
#  4   SensorID  4398 non-null   object
#  5   DateTime  4398 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 206.3+ KB

# %%
#Show first rows of dataset
data_mult.head()
# Out:
#     ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 0  105    24.00     28.00  179.6.8.120  ROLIN-01  2025-01-15 15:53:17
# 1  106    23.50     27.00  179.6.8.120  ROLIN-01  2025-01-15 15:54:19
# 2  107    23.00     24.25  179.6.8.120  ROLIN-01  2025-01-15 15:56:19
# 3  108    22.75     24.25  179.6.8.120  ROLIN-01  2025-01-15 15:57:19
# 4  109    22.25     24.25  179.6.8.120  ROLIN-01  2025-01-15 15:58:20

# %%
#Show statistics of dataset
data_mult.describe()
# Out:
#                 ID      Temp In     Temp Out
# count  4398.000000  4398.000000  4398.000000
# mean   2303.500000    11.689859    16.031037
# std    1269.737571     7.222053     8.704021
# min     105.000000     1.750000     7.000000
# 25%    1204.250000     5.250000     9.000000
# 50%    2303.500000     8.750000    11.500000
# 75%    3402.750000    17.000000    21.750000
# max    4502.000000    30.250000    40.000000

# %%
#Show last rows of dataset
data_mult.tail()
# Out:
#         ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 4393  4498     5.00     10.25  179.6.8.120  ROLIN-01  2025-01-18 20:33:40
# 4394  4499     5.00     10.25  179.6.8.120  ROLIN-01  2025-01-18 20:34:40
# 4395  4500     5.25     10.25  179.6.8.120  ROLIN-01  2025-01-18 20:35:40
# 4396  4501     5.50     10.50  179.6.8.120  ROLIN-01  2025-01-18 20:36:40
# 4397  4502     5.50     10.25  179.6.8.120  ROLIN-01  2025-01-18 20:37:40

# %%
#Show sample of rows
data_mult.sample(5)
# Out:
#         ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 4165  4270    13.75     17.00  179.6.8.120  ROLIN-01  2025-01-18 16:44:35
# 1612  1717     8.00     10.25  179.6.8.120  ROLIN-01  2025-01-16 22:01:52
# 2953  3058     5.25     10.25  179.6.8.120  ROLIN-01  2025-01-17 20:17:06
# 2598  2703    25.50     33.00  179.6.8.120  ROLIN-01  2025-01-17 14:23:15
# 2637  2742    25.25     31.25  179.6.8.120  ROLIN-01  2025-01-17 15:02:07

# %%
#Show highest values of Output Temperature
data_mult.loc[data_mult['Temp Out'] > 38]
# Out:
#         ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 1077  1182    29.25     38.25  179.6.8.120  ROLIN-01  2025-01-16 10:55:51
# 1078  1183    28.50     38.25  179.6.8.120  ROLIN-01  2025-01-16 10:56:51
# 1079  1184    30.25     38.50  179.6.8.120  ROLIN-01  2025-01-16 10:57:53
# 1080  1185    30.00     39.25  179.6.8.120  ROLIN-01  2025-01-16 10:58:52
# 1081  1186    29.50     39.00  179.6.8.120  ROLIN-01  2025-01-16 11:00:53
# 1113  1218    29.00     38.25  179.6.8.120  ROLIN-01  2025-01-16 11:37:01
# 1114  1219    29.50     39.00  179.6.8.120  ROLIN-01  2025-01-16 11:38:01
# 1115  1220    28.75     39.25  179.6.8.120  ROLIN-01  2025-01-16 11:39:01
# 1116  1221    28.75     39.25  179.6.8.120  ROLIN-01  2025-01-16 11:40:01
# 1117  1222    28.50     39.25  179.6.8.120  ROLIN-01  2025-01-16 11:41:01
# 1118  1223    29.00     39.00  179.6.8.120  ROLIN-01  2025-01-16 11:43:01
# 1119  1224    29.00     38.75  179.6.8.120  ROLIN-01  2025-01-16 11:44:01
# ...

# %%
#Percentage of unique rows (records)
data_mult.nunique() / len(data_mult)
# Out:
# ID          1.000000
# Temp In     0.025466
# Temp Out    0.030014
# ClientIP    0.000227
# SensorID    0.000227
# DateTime    1.000000
# dtype: float64

# %%
#Percentage of empty rows (records) ...
data_mult.isna().sum() / len(data_mult)
# Out:
# ID          0.0
# Temp In     0.0
# Temp Out    0.0
# ClientIP    0.0
# SensorID    0.0
# DateTime    0.0
# dtype: float64

# %%
#Data types
data_mult.dtypes
# Out:
# ID            int64
# Temp In     float64
# Temp Out    float64
# ClientIP     object
# SensorID     object
# DateTime     object
# dtype: object

# %%
#Data statistics
data_mult.describe()
# Out:
#                 ID      Temp In     Temp Out
# count  4398.000000  4398.000000  4398.000000
# mean   2303.500000    11.689859    16.031037
# std    1269.737571     7.222053     8.704021
# min     105.000000     1.750000     7.000000
# 25%    1204.250000     5.250000     9.000000
# 50%    2303.500000     8.750000    11.500000
# 75%    3402.750000    17.000000    21.750000
# max    4502.000000    30.250000    40.000000

# %%
#Create a matrix to represent the x-axis of a graph
#x1 = np.arange(0, len(y), 1)
x1 = np.arange(0, len(data_mult["ID"]), 1)
x1
# Out:
# array([   0,    1,    2, ..., 4395, 4396, 4397])

# %%
y1 = data_mult[["Temp In"]]
print(y1)
# Out:
#       Temp In
# 0       24.00
# 1       23.50
# 2       23.00
# 3       22.75
# 4       22.25
# ...       ...
# 4393     5.00
# 4394     5.00
# 4395     5.25
# 4396     5.50
# 4397     5.50
#
# [4398 rows x 1 columns]

# %%
#Power vs Time
plt.figure(figsize=(24,10))
plt.title("Temp In vs Tiempo", fontsize = 16)
plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x1, y1, lw=0.8, color="blue", label="Temp In")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Temp In', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#Show Voltage Variable
y2 = data_mult[["Temp Out"]]
print(y2)
# Out:
#       Temp Out
# 0        28.00
# 1        27.00
# 2        24.25
# 3        24.25
# 4        24.25
# ...        ...
# 4393     10.25
# 4394     10.25
# 4395     10.25
# 4396     10.50
# 4397     10.25
#
# [4398 rows x 1 columns]

# %%
#Voltage vs Time
plt.figure(figsize=(24,10))
plt.title("Temp Out vs Tiempo", fontsize = 16)
plt.scatter(x1, y2, s=5, color="red", label="Temp Out")
plt.plot(x1, y2, lw=0.8, color="blue", label="Temp Out")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Temp Out', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
# create figure
fig = plt.figure(figsize=(20, 10))
plt.title("Temp In - Temp Out vs Tiempo", fontsize = 16)

# setting values to rows and column variables
rows = 2
columns = 1

# reading images
#Image1 = cv2.imread('Image1.jpg')
#Image2 = cv2.imread('Image2.jpg')
#Image3 = cv2.imread('Image3.jpg')
#Image4 = cv2.imread('Image4.jpg')

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

# showing image
#Power vs Time
plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x1, y1, lw=0.8, color="blue", label="Temp In")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Panel', fontsize = 16)
#plt.legend(fontsize = 16)
plt.grid()
#plt.imshow(Image1)
#plt.axis('off')
#plt.title("First")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)

# showing image
#Voltage vs Time
plt.scatter(x1, y2, s=5, color="red", label="Temp Out")
plt.plot(x1, y2, lw=0.8, color="blue", label="Temp Out")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Batería', fontsize = 16)
#plt.legend(fontsize = 16)
plt.grid()

#plt.imshow(Image2)
#plt.axis('off')
#plt.title("Second")

# showing image
#plt.imshow(Image4)
#plt.axis('off')
#plt.title("Fourth")
#plt.grid()
plt.show()

# %%
#Temp In - Temp Out vs Time
plt.figure(figsize=(24,10))
plt.title("Temp In - Temp Out vs Time", fontsize = 16)
#plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x1, y1, lw=0.8, color="green", label="Temp In")
plt.plot(x1, y2, lw=0.8, color="red", label="Temp Out")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Temp In - Temp Out', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#The "read_csv" method allows us to read a CSV
data_mult = pd.read_csv("gdrive/MyDrive/Colab Notebooks/TEMPTERM/csv/ALL-tempterm-with-control.txt", header = None)
#Cov = pd.read_csv("path/to/file.txt", sep='\t', header=None)
data_mult.columns = ["ID", "Temp In", "Temp Out", "ClientIP", "SensorID", "DateTime"]

# %%
#Show information about dataset
data_mult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3022 entries, 0 to 3021
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        3022 non-null   int64
#  1   Temp In   3022 non-null   float64
#  2   Temp Out  3022 non-null   float64
#  3   ClientIP  3022 non-null   object
#  4   SensorID  3022 non-null   object
#  5   DateTime  3022 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 141.8+ KB

# %%
#Show first rows of dataset
data_mult.head()
# Out:
#      ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 0  7685    36.25     26.75  179.6.8.120  ROLIN-01  2025-04-09 13:54:17
# 1  7686    35.25     25.75  179.6.8.120  ROLIN-01  2025-04-09 13:55:17
# 2  7687    35.50     25.00  179.6.8.120  ROLIN-01  2025-04-09 13:56:17
# 3  7688    36.75     25.75  179.6.8.120  ROLIN-01  2025-04-09 13:57:17
# 4  7689    35.50     26.00  179.6.8.120  ROLIN-01  2025-04-09 13:58:16

# %%
#Show statistics of dataset
data_mult.describe()
# Out:
#                  ID      Temp In     Temp Out
# count   3022.000000  3022.000000  3022.000000
# mean    9195.500000    14.374504    15.754467
# std      872.520582    12.949648     8.124717
# min     7685.000000     0.750000     5.000000
# 25%     8440.250000     4.500000     9.000000
# 50%     9195.500000     8.000000    13.000000
# 75%     9950.750000    24.000000    23.000000
# max    10706.000000    43.500000    43.000000

# %%
#Show last rows of dataset
data_mult.tail()
# Out:
#          ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 3017  10702    14.75     17.75  179.6.8.120  ROLIN-01  2025-04-11 16:07:28
# 3018  10703    14.50     18.25  179.6.8.120  ROLIN-01  2025-04-11 16:08:28
# 3019  10704    14.50     18.75  179.6.8.120  ROLIN-01  2025-04-11 16:09:28
# 3020  10705    15.25     18.75  179.6.8.120  ROLIN-01  2025-04-11 16:10:27
# 3021  10706    15.00     19.25  179.6.8.120  ROLIN-01  2025-04-11 16:11:27

# %%
#Show sample of rows
data_mult.sample(5)
# Out:
#         ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 780   8465     2.25      6.25  179.6.8.120  ROLIN-01  2025-04-10 02:56:36
# 1883  9568     5.00      9.75  179.6.8.120  ROLIN-01  2025-04-10 21:16:10
# 411   8096     4.25      8.75  179.6.8.120  ROLIN-01  2025-04-09 20:47:27
# 933   8618     1.75      6.00  179.6.8.120  ROLIN-01  2025-04-10 05:29:04
# 590   8275     4.25      8.25  179.6.8.120  ROLIN-01  2025-04-09 23:46:08

# %%
#Show highest values of Output Temperature
data_mult.loc[data_mult['Temp Out'] > 35]
# Out:
#          ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 2889  10574    39.00     36.25  179.6.8.120  ROLIN-01  2025-04-11 13:59:52
# 2890  10575    38.50     38.00  179.6.8.120  ROLIN-01  2025-04-11 14:00:52
# 2897  10582    38.00     36.75  179.6.8.120  ROLIN-01  2025-04-11 14:07:51
# 2898  10583    37.75     35.25  179.6.8.120  ROLIN-01  2025-04-11 14:08:50
# 2907  10592    37.75     36.00  179.6.8.120  ROLIN-01  2025-04-11 14:17:49
# 2914  10599    36.25     37.00  179.6.8.120  ROLIN-01  2025-04-11 14:24:47
# 2915  10600    38.25     38.25  179.6.8.120  ROLIN-01  2025-04-11 14:25:47
# 2916  10601    38.25     39.75  179.6.8.120  ROLIN-01  2025-04-11 14:26:47
# 2917  10602    39.25     38.00  179.6.8.120  ROLIN-01  2025-04-11 14:27:47
# 2918  10603    40.00     36.50  179.6.8.120  ROLIN-01  2025-04-11 14:28:47
# 2922  10607    40.25     41.25  179.6.8.120  ROLIN-01  2025-04-11 14:32:46
# ...

# %%
#Show highest values of Output Temperature
data_mult.loc[(data_mult['Temp Out'] > 18) & (data_mult['Temp Out'] < 22)]
# Out:
#          ID  Temp In  Temp Out     ClientIP  SensorID             DateTime
# 90     7775    23.50     21.75  179.6.8.120  ROLIN-01  2025-04-09 15:24:05
# 91     7776    22.75     21.50  179.6.8.120  ROLIN-01  2025-04-09 15:25:05
# 92     7777    22.00     21.25  179.6.8.120  ROLIN-01  2025-04-09 15:26:04
# 96     7781    21.00     20.75  179.6.8.120  ROLIN-01  2025-04-09 15:30:04
# 97     7782    20.75     21.50  179.6.8.120  ROLIN-01  2025-04-09 15:31:04
# ...     ...      ...       ...          ...       ...                  ...
# 3015  10700    14.75     18.75  179.6.8.120  ROLIN-01  2025-04-11 16:05:29
# 3018  10703    14.50     18.25  179.6.8.120  ROLIN-01  2025-04-11 16:08:28
# 3019  10704    14.50     18.75  179.6.8.120  ROLIN-01  2025-04-11 16:09:28
# 3020  10705    15.25     18.75  179.6.8.120  ROLIN-01  2025-04-11 16:10:27
# 3021  10706    15.00     19.25  179.6.8.120  ROLIN-01  2025-04-11 16:11:27
#
# [302 rows x 6 columns]

# %%
#Percentage of unique rows (records)
data_mult.nunique() / len(data_mult)
# Out:
# ID          1.000000
# Temp In     0.055923
# Temp Out    0.043680
# ClientIP    0.000993
# SensorID    0.000331
# DateTime    1.000000
# dtype: float64

# %%
#Percentage of empty rows (records) ...
data_mult.isna().sum() / len(data_mult)
# Out:
# ID          0.0
# Temp In     0.0
# Temp Out    0.0
# ClientIP    0.0
# SensorID    0.0
# DateTime    0.0
# dtype: float64

# %%
#Data types
data_mult.dtypes
# Out:
# ID            int64
# Temp In     float64
# Temp Out    float64
# ClientIP     object
# SensorID     object
# DateTime     object
# dtype: object

# %%
#Data statistics
data_mult.describe()
# Out:
#                  ID      Temp In     Temp Out
# count   3022.000000  3022.000000  3022.000000
# mean    9195.500000    14.374504    15.754467
# std      872.520582    12.949648     8.124717
# min     7685.000000     0.750000     5.000000
# 25%     8440.250000     4.500000     9.000000
# 50%     9195.500000     8.000000    13.000000
# 75%     9950.750000    24.000000    23.000000
# max    10706.000000    43.500000    43.000000

# %%
#Create a matrix to represent the x-axis of a graph
#x1 = np.arange(0, len(y), 1)
x1 = np.arange(0, len(data_mult["ID"]), 1)
x1
# Out:
# array([   0,    1,    2, ..., 3019, 3020, 3021])

# %%
y1 = data_mult[["Temp In"]]
print(y1)
# Out:
#       Temp In
# 0       36.25
# 1       35.25
# 2       35.50
# 3       36.75
# 4       35.50
# ...       ...
# 3017    14.75
# 3018    14.50
# 3019    14.50
# 3020    15.25
# 3021    15.00
#
# [3022 rows x 1 columns]

# %%
#Power vs Time
plt.figure(figsize=(24,10))
plt.title("Temp In vs Tiempo", fontsize = 16)
plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x1, y1, lw=0.8, color="blue", label="Temp In")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Temp In', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#Show Voltage Variable
y2 = data_mult[["Temp Out"]]
print(y2)
# Out:
#       Temp Out
# 0        26.75
# 1        25.75
# 2        25.00
# 3        25.75
# 4        26.00
# ...        ...
# 3017     17.75
# 3018     18.25
# 3019     18.75
# 3020     18.75
# 3021     19.25
#
# [3022 rows x 1 columns]

# %%
#Voltage vs Time
plt.figure(figsize=(24,10))
plt.title("Temp Out vs Tiempo", fontsize = 16)
plt.scatter(x1, y2, s=5, color="red", label="Temp Out")
plt.plot(x1, y2, lw=0.8, color="blue", label="Temp Out")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Temp Out', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
# create figure
fig = plt.figure(figsize=(20, 10))
plt.title("Temp In - Temp Out vs Tiempo", fontsize = 16)

# setting values to rows and column variables
rows = 2
columns = 1

# reading images
#Image1 = cv2.imread('Image1.jpg')
#Image2 = cv2.imread('Image2.jpg')
#Image3 = cv2.imread('Image3.jpg')
#Image4 = cv2.imread('Image4.jpg')

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

# showing image
#Power vs Time
plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x1, y1, lw=0.8, color="blue", label="Temp In")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Panel', fontsize = 16)
#plt.legend(fontsize = 16)
plt.grid()
#plt.imshow(Image1)
#plt.axis('off')
#plt.title("First")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)

# showing image
#Voltage vs Time
plt.scatter(x1, y2, s=5, color="red", label="Temp Out")
plt.plot(x1, y2, lw=0.8, color="blue", label="Temp Out")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Batería', fontsize = 16)
#plt.legend(fontsize = 16)
plt.grid()

#plt.imshow(Image2)
#plt.axis('off')
#plt.title("Second")

# showing image
#plt.imshow(Image4)
#plt.axis('off')
#plt.title("Fourth")
#plt.grid()
plt.show()

# %%
#Temp In - Temp Out vs Time
plt.figure(figsize=(24,10))
plt.title("Temp In - Temp Out vs Time", fontsize = 16)
#plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x1, y1, lw=0.8, color="green", label="Temp In")
plt.plot(x1, y2, lw=0.8, color="red", label="Temp Out")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Temp In - Temp Out', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()
